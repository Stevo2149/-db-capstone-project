# %%
# !pip install mysql-connector-python
# Out:
# ...
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    --------------------------- ------------ 11.3/16.4 MB 64.0 MB/s eta 0:00:01
#    ---------------------------------------- 16.4/16.4 MB 54.2 MB/s eta 0:00:00
# ...

# %%
import mysql.connector as connector

# %%
# Replace these with your actual credentials
config = {
    'user': 'admin1',
    'password': 'Est3f@ni@1162024',
    'host': 'localhost',      # or your server's IP address
    'database': 'littlelemondb',
    'port': 3306              # default MySQL port
}

try:
    conn = connector.connect(**config)
    cursor = conn.cursor()
    cursor.execute("SELECT DATABASE();")
    result = cursor.fetchone()
    print("Connected to database:", result)
except connector.Error as err:
    print("Error:", err)
finally:
    if 'cursor' in locals():
        cursor.close()
    if 'conn' in locals() and conn.is_connected():
        conn.close()
# Out:
# Connected to database: ('littlelemondb',)

# %%
try:
    conn = connector.connect(**config)
    cursor = conn.cursor()
    cursor.execute("SELECT DATABASE();")
    result = cursor.fetchone()
    print("Connected to database:", result)

    # Run your SHOW TABLES query here, while cursor is open
    show_tables_query = "SHOW tables"
    cursor.execute(show_tables_query)
    tables = cursor.fetchall()
    print("Tables in database:")
    for table in tables:
        print(table[0])

except mysql.connector.Error as err:
    print("Error:", err)
finally:
    if 'cursor' in locals():
        cursor.close()
    if 'conn' in locals() and conn.is_connected():
        conn.close()
# Out:
# Connected to database: ('littlelemondb',)
# Tables in database:
# bookings
# customers
# menuitems
# menus
# orderdeliverystatus
# orders
# orderview
# staff

# %%
try:
    conn = connector.connect(**config)
    cursor = conn.cursor()
    cursor.execute("SELECT DATABASE();")
    result = cursor.fetchone()
    print("Connected to database:", result)

    # Run your SELECT query
    orders60_tables_query = """
    SELECT c.FullName, c.ContactNumber, c.Email
    FROM Customers c
    JOIN Orders o ON c.CustomerID = o.customerID
    WHERE o.TotalCost >= 60
    """
    cursor.execute(orders60_tables_query)
    # Get column names using column_names property
    column_names = cursor.column_names
    print(" | ".join(column_names))  # Print column names as header

    rows = cursor.fetchall()
    for row in rows:
        print(" | ".join(str(item) for item in row))

except connector.Error as err:
    print("Error:", err)
finally:
    if 'cursor' in locals():
        cursor.close()
    if 'conn' in locals() and conn.is_connected():
        conn.close()
# Out:
# Connected to database: ('littlelemondb',)
# FullName | ContactNumber | Email
# Alice Smith | 1234567890 | alice@example.com
# Bob Jones | 0987654321 | bob@example.com
